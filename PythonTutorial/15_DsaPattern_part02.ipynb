# %%
## Largest Element in an Array

def largestElement(nums: list[int]):

    large = float("-inf") ## - infinity value

    n = len(nums)

    for i in range(0, n):
        if nums[i] > large:
            large = nums[i]
    return large


nums = [55, 32, -97, 99, 3, 67]
negativeNums = [-55, -32, -97, -99, -3, -67]
print(largestElement(negativeNums))
# Out:
# -3

# %%
## Smallest Element in an Array

def SmallestElement(nums: list[int]):

    large = float("+inf") ## - infinity value

    n = len(nums)

    for i in range(0, n):
        if nums[i] < large:
            large = nums[i]
    return large


nums = [55, 32, -97, 99, 3, 67]
negativeNums = [-55, -32, -97, -99, -3, -67]
print(SmallestElement(negativeNums))
# Out:
# -99

# %%
## Find the 2nd Largest Element in an Array

def secondLargest(nums: list[int]):
    
    large = float("+inf") ## - infinity value
    
    n = len(nums)
    
    for i in range(0, n):
        if nums[i] < large:
            large = nums[i]
    return large
    

nums = [55, 32, -97, 99, 3, 67]
negativeNums = [-55, -32, -97, -99, -3, -67]
print(secondLargest(negativeNums))
